# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/data (1).csv')
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.head(5)
df.tail(6)
# Out:
#       id  season       city        date                  team1  \
# 571  572    2016    Kolkata  2016-05-22  Kolkata Knight Riders
# 572  573    2016     Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016      Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27          Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 571          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   season  577 non-null    int64
#  1   team1   577 non-null    object
#  2   team2   577 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 13.6+ KB

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.shape
# Out:
# (577, 18)

# %%
df['team1'],[df['team2']]
# Out:
# (0      Kolkata Knight Riders
#  1        Chennai Super Kings
#  2           Rajasthan Royals
#  3             Mumbai Indians
#  4            Deccan Chargers
#                 ...
#  572         Delhi Daredevils
#  573            Gujarat Lions
#  574      Sunrisers Hyderabad
#  575            Gujarat Lions
#  576      Sunrisers Hyderabad
#  Name: team1, Length: 577, dtype: object,
#  [0      Royal Challengers Bangalore
#   1                  Kings XI Punjab
#   2                 Delhi Daredevils
#   3      Royal Challengers Bangalore
#   4            Kolkata Knight Riders
#                     ...
#   572    Royal Challengers Bangalore
#   573    Royal Challengers Bangalore
#   574          Kolkata Knight Riders
#   575            Sunrisers Hyderabad
#   576    Royal Challengers Bangalore
#   Name: team2, Length: 577, dtype: object])

# %%
df['season'],[df['winner']],[df['player_of_match']]
# Out:
# (0      2008
#  1      2008
#  2      2008
#  3      2008
#  4      2008
#         ...
#  572    2016
#  573    2016
#  574    2016
#  575    2016
#  576    2016
#  Name: season, Length: 577, dtype: int64,
#  [0            Kolkata Knight Riders
#   1              Chennai Super Kings
#   2                 Delhi Daredevils
#   3      Royal Challengers Bangalore
#   4            Kolkata Knight Riders
#                     ...
#   572    Royal Challengers Bangalore
#   573    Royal Challengers Bangalore
#   574            Sunrisers Hyderabad
#   575            Sunrisers Hyderabad
#   576            Sunrisers Hyderabad
#   Name: winner, Length: 577, dtype: object],
#  [0         BB McCullum
#   1          MEK Hussey
#   2         MF Maharoof
#   3          MV Boucher
#   4           DJ Hussey
#               ...
#   572           V Kohli
#   573    AB de Villiers
#   574      MC Henriques
#   575         DA Warner
#   576       BCJ Cutting
# ...

# %%
df['win_by_runs'].max()
# Out:
# 144

# %%
df['win_by_runs'].mean()
# Out:
# 13.7157712305026

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object    2
# int64     1
# Name: count, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=577, step=1)

# %%
df['season'].describe()
# Out:
# count     577.000000
# mean     2012.029463
# std         2.486247
# min      2008.000000
# 25%      2010.000000
# 50%      2012.000000
# 75%      2014.000000
# max      2016.000000
# Name: season, dtype: float64

# %%
df.sort_values(by='season')
# Out:
#      season                        team1                        team2
# 0      2008        Kolkata Knight Riders  Royal Challengers Bangalore
# 31     2008          Chennai Super Kings              Kings XI Punjab
# 32     2008        Kolkata Knight Riders              Deccan Chargers
# 33     2008             Delhi Daredevils             Rajasthan Royals
# 34     2008  Royal Challengers Bangalore              Kings XI Punjab
# ..      ...                          ...                          ...
# 541    2016      Rising Pune Supergiants                Gujarat Lions
# 542    2016             Delhi Daredevils        Kolkata Knight Riders
# 543    2016          Sunrisers Hyderabad  Royal Challengers Bangalore
# 545    2016      Rising Pune Supergiants               Mumbai Indians
# 576    2016          Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [577 rows x 3 columns]

# %%
df.sort_values(by='season').head()
# Out:
#     season                        team1                        team2
# 0     2008        Kolkata Knight Riders  Royal Challengers Bangalore
# 31    2008          Chennai Super Kings              Kings XI Punjab
# 32    2008        Kolkata Knight Riders              Deccan Chargers
# 33    2008             Delhi Daredevils             Rajasthan Royals
# 34    2008  Royal Challengers Bangalore              Kings XI Punjab

# %%
df.sort_values(by='season').tail()
# Out:
#      season                    team1                        team2
# 541    2016  Rising Pune Supergiants                Gujarat Lions
# 542    2016         Delhi Daredevils        Kolkata Knight Riders
# 543    2016      Sunrisers Hyderabad  Royal Challengers Bangalore
# 545    2016  Rising Pune Supergiants               Mumbai Indians
# 576    2016      Sunrisers Hyderabad  Royal Challengers Bangalore

# %%
df.sort_values(by='season',ascending=False).head()
# Out:
#      season                        team1                        team2
# 576    2016          Sunrisers Hyderabad  Royal Challengers Bangalore
# 546    2016  Royal Challengers Bangalore        Kolkata Knight Riders
# 544    2016              Kings XI Punjab                Gujarat Lions
# 543    2016          Sunrisers Hyderabad  Royal Challengers Bangalore
# 542    2016             Delhi Daredevils        Kolkata Knight Riders

# %%
df.sort_values(by='season',ascending=True).head()
# Out:
#     season                        team1                        team2
# 0     2008        Kolkata Knight Riders  Royal Challengers Bangalore
# 31    2008          Chennai Super Kings              Kings XI Punjab
# 32    2008        Kolkata Knight Riders              Deccan Chargers
# 33    2008             Delhi Daredevils             Rajasthan Royals
# 34    2008  Royal Challengers Bangalore              Kings XI Punjab

# %%
df.sort_values(by='season',ascending=False).tail()
# Out:
#     season                        team1                        team2
# 35    2008        Kolkata Knight Riders             Delhi Daredevils
# 34    2008  Royal Challengers Bangalore              Kings XI Punjab
# 33    2008             Delhi Daredevils             Rajasthan Royals
# 32    2008        Kolkata Knight Riders              Deccan Chargers
# 0     2008        Kolkata Knight Riders  Royal Challengers Bangalore

# %%
df['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
dt=df.dropna()
print(dt.to_string())
# Out:
#      season                        team1                        team2
# 0      2008        Kolkata Knight Riders  Royal Challengers Bangalore
# 1      2008          Chennai Super Kings              Kings XI Punjab
# 2      2008             Rajasthan Royals             Delhi Daredevils
# 3      2008               Mumbai Indians  Royal Challengers Bangalore
# 4      2008              Deccan Chargers        Kolkata Knight Riders
# 5      2008              Kings XI Punjab             Rajasthan Royals
# 6      2008              Deccan Chargers             Delhi Daredevils
# 7      2008          Chennai Super Kings               Mumbai Indians
# 8      2008              Deccan Chargers             Rajasthan Royals
# 9      2008              Kings XI Punjab               Mumbai Indians
# 10     2008  Royal Challengers Bangalore             Rajasthan Royals
# 11     2008        Kolkata Knight Riders          Chennai Super Kings
# ...

# %%
dt=df.dropna()
dt=df.fillna(50,inplace=False)
print(dt.to_string())
# Out:
#      season                        team1                        team2
# 0      2008        Kolkata Knight Riders  Royal Challengers Bangalore
# 1      2008          Chennai Super Kings              Kings XI Punjab
# 2      2008             Rajasthan Royals             Delhi Daredevils
# 3      2008               Mumbai Indians  Royal Challengers Bangalore
# 4      2008              Deccan Chargers        Kolkata Knight Riders
# 5      2008              Kings XI Punjab             Rajasthan Royals
# 6      2008              Deccan Chargers             Delhi Daredevils
# 7      2008          Chennai Super Kings               Mumbai Indians
# 8      2008              Deccan Chargers             Rajasthan Royals
# 9      2008              Kings XI Punjab               Mumbai Indians
# 10     2008  Royal Challengers Bangalore             Rajasthan Royals
# 11     2008        Kolkata Knight Riders          Chennai Super Kings
# ...

# %%
#dt=df.dropna()
dt=df.fillna(50,inplace=True)
print(dt)
# Out:
# None

# %%
df.fillna(100,inplace=True)
print(df)
# Out:
#      season                  team1                        team2
# 0      2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 1      2008    Chennai Super Kings              Kings XI Punjab
# 2      2008       Rajasthan Royals             Delhi Daredevils
# 3      2008         Mumbai Indians  Royal Challengers Bangalore
# 4      2008        Deccan Chargers        Kolkata Knight Riders
# ..      ...                    ...                          ...
# 572    2016       Delhi Daredevils  Royal Challengers Bangalore
# 573    2016          Gujarat Lions  Royal Challengers Bangalore
# 574    2016    Sunrisers Hyderabad        Kolkata Knight Riders
# 575    2016          Gujarat Lions          Sunrisers Hyderabad
# 576    2016    Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [577 rows x 3 columns]

# %%
df['season'].fillna(100,inplace=True)
print(df)
# Out:
#      season                  team1                        team2
# 0      2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 1      2008    Chennai Super Kings              Kings XI Punjab
# 2      2008       Rajasthan Royals             Delhi Daredevils
# 3      2008         Mumbai Indians  Royal Challengers Bangalore
# 4      2008        Deccan Chargers        Kolkata Knight Riders
# ..      ...                    ...                          ...
# 572    2016       Delhi Daredevils  Royal Challengers Bangalore
# 573    2016          Gujarat Lions  Royal Challengers Bangalore
# 574    2016    Sunrisers Hyderabad        Kolkata Knight Riders
# 575    2016          Gujarat Lions          Sunrisers Hyderabad
# 576    2016    Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [577 rows x 3 columns]

# %%
df['season'].fillna(100,inplace=True)
print(df)
df.describe()
# Out:
#      season                  team1                        team2
# 0      2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 1      2008    Chennai Super Kings              Kings XI Punjab
# 2      2008       Rajasthan Royals             Delhi Daredevils
# 3      2008         Mumbai Indians  Royal Challengers Bangalore
# 4      2008        Deccan Chargers        Kolkata Knight Riders
# ..      ...                    ...                          ...
# 572    2016       Delhi Daredevils  Royal Challengers Bangalore
# 573    2016          Gujarat Lions  Royal Challengers Bangalore
# 574    2016    Sunrisers Hyderabad        Kolkata Knight Riders
# 575    2016          Gujarat Lions          Sunrisers Hyderabad
# 576    2016    Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [577 rows x 3 columns]
#             season
# count   577.000000
# mean   2012.029463
# std       2.486247
# min    2008.000000
# 25%    2010.000000
# 50%    2012.000000
# 75%    2014.000000
# ...

# %%
df.nunique()
# Out:
# season     9
# team1     13
# team2     13
# dtype: int64

# %%
df.isnull()
# Out:
#      season  team1  team2
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# ..      ...    ...    ...
# 572   False  False  False
# 573   False  False  False
# 574   False  False  False
# 575   False  False  False
# 576   False  False  False
#
# [577 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# season    0
# team1     0
# team2     0
# dtype: int64

# %%
print(df.iloc[0])
# Out:
# season                           2008
# team1           Kolkata Knight Riders
# team2     Royal Challengers Bangalore
# Name: 0, dtype: object

# %%
print(df.iloc[1])
# Out:
# season                   2008
# team1     Chennai Super Kings
# team2         Kings XI Punjab
# Name: 1, dtype: object

# %%
print(df.iloc[:,1:3])
# Out:
#                      team1                        team2
# 0    Kolkata Knight Riders  Royal Challengers Bangalore
# 1      Chennai Super Kings              Kings XI Punjab
# 2         Rajasthan Royals             Delhi Daredevils
# 3           Mumbai Indians  Royal Challengers Bangalore
# 4          Deccan Chargers        Kolkata Knight Riders
# ..                     ...                          ...
# 572       Delhi Daredevils  Royal Challengers Bangalore
# 573          Gujarat Lions  Royal Challengers Bangalore
# 574    Sunrisers Hyderabad        Kolkata Knight Riders
# 575          Gujarat Lions          Sunrisers Hyderabad
# 576    Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [577 rows x 2 columns]

# %%
print(df.iloc[1:4,1:4])
# Out:
#                  team1                        team2
# 1  Chennai Super Kings              Kings XI Punjab
# 2     Rajasthan Royals             Delhi Daredevils
# 3       Mumbai Indians  Royal Challengers Bangalore

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                            team2                  team1  season
# 0    Royal Challengers Bangalore  Kolkata Knight Riders    2008
# 1                Kings XI Punjab    Chennai Super Kings    2008
# 2               Delhi Daredevils       Rajasthan Royals    2008
# 3    Royal Challengers Bangalore         Mumbai Indians    2008
# 4          Kolkata Knight Riders        Deccan Chargers    2008
# ..                           ...                    ...     ...
# 572  Royal Challengers Bangalore       Delhi Daredevils    2016
# 573  Royal Challengers Bangalore          Gujarat Lions    2016
# 574        Kolkata Knight Riders    Sunrisers Hyderabad    2016
# 575          Sunrisers Hyderabad          Gujarat Lions    2016
# 576  Royal Challengers Bangalore    Sunrisers Hyderabad    2016
#
# [577 rows x 3 columns]

# %%
df.sort_index(axis=1,ascending=False)
print(df.iloc[1:4,1:4])
# Out:
#                  team1                        team2
# 1  Chennai Super Kings              Kings XI Punjab
# 2     Rajasthan Royals             Delhi Daredevils
# 3       Mumbai Indians  Royal Challengers Bangalore

# %%
sns.pairplot(df,hue='team1')

# %%
sns.pairplot(df,hue='team2')

# %%
sns.barplot()
# Out:
# <Axes: >

# %%
sns.barplot(x='team1',y='team2',data=df)
# Out:
# <Axes: xlabel='team1', ylabel='team2'>

# %%
sns.barplot(x='season',y='team1',data=df)
# Out:
# <Axes: xlabel='season', ylabel='team1'>

# %%
sns.barplot(x='season',y='team2',data=df)
# Out:
# <Axes: xlabel='season', ylabel='team2'>

# %%
sns.jointplot(x='season',y='team1',data=df)

# %%
sns.jointplot(x='season',y='team2',data=df)

# %%
sns.scatterplot(x='season',y='team1',data=df)
# Out:
# <Axes: xlabel='season', ylabel='team1'>

# %%
sns.scatterplot(x='season',y='team2',data=df)
# Out:
# <Axes: xlabel='season', ylabel='team2'>

# %%
import seaborn as sns

# %%
sns.displot(x='season',data=df)

# %%
sns.displot(x='team1',data=df)

# %%
sns.displot(x='team2',data=df)

# %%
import matplotlib.pyplot as plt
matches_per_season = df['season'].value_counts().sort_index()
plt.figure()
matches_per_season.plot(kind='bar')
plt.title('Number of Matches per Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches')
plt.show()

# %%
import matplotlib.pyplot as plt
wins_by_team = df['season'].value_counts()
plt.figure(figsize=(12, 6))
wins_by_team.plot(kind='bar')
plt.title('Wins by Team')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.show()

# %%
import matplotlib.pyplot as plt
matches_per_season = df['season'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
matches_per_season.plot(kind='bar')
plt.title('Number of Matches per Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches')
plt.show()
